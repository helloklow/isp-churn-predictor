# %%
import duckdb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# connect to local duckdb db file (same file dbt has been writing to)
con = duckdb.connect("../data/isp_churn.duckdb")

# query mart_churn table (clean, ft-eng table)
# load it directly into a pandas df
df = con.execute("SELECT * FROM mart_churn").fetchdf()

# check rows and columns
print(df.shape)

# preview first 5 rows
df.head()
# Out:
# (72274, 15)
#    customer_id  has_tv  has_movies  subscription_age  avg_bill  \
# 0           15       1           0             11.95        25
# 1           18       0           0              8.22         0
# 2           23       1           0              8.91        16
# 3           27       0           0              6.87        21
# 4           34       0           0              6.39         0
#
#    remaining_contract  service_failures  avg_download  avg_upload  \
# 0                0.14                 0           8.4         2.3
# 1                0.00                 0           0.0         0.0
# 2                0.00                 0          13.7         0.9
# 3                0.00                 1           0.0         0.0
# 4                0.00                 0           0.0         0.0
#
#    over_download_limit  is_month_to_month  churned  addon_count  \
# 0                    0                  0        0            1
# ...

# %%
# summarize columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72274 entries, 0 to 72273
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   customer_id            72274 non-null  int64
#  1   has_tv                 72274 non-null  int64
#  2   has_movies             72274 non-null  int64
#  3   subscription_age       72274 non-null  float64
#  4   avg_bill               72274 non-null  int64
#  5   remaining_contract     72274 non-null  float64
#  6   service_failures       72274 non-null  int64
#  7   avg_download           71893 non-null  float64
#  8   avg_upload             71893 non-null  float64
#  9   over_download_limit    72274 non-null  int64
#  10  is_month_to_month      72274 non-null  int32
#  11  churned                72274 non-null  int64
#  12  addon_count            72274 non-null  int64
#  13  download_upload_ratio  60219 non-null  float64
# ...
